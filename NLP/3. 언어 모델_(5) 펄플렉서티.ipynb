# %% [markdown]
# ## 펄플렉서티(Perplexity, PPL)
# - https://wikidocs.net/21697
# - 조금은 부정확할 수는 있어도 테스트 데이터에 대해서 빠르게 식으로 계산되는 더 간단한 평가 방법
# - 모델 내에서 자신의 성능을 수치화하여 결과를 내놓는 펄플렉서티(perplexity)

# %% [markdown]
# ### 언어 모델의 평가 방법(Evaluation metric) : PPL
# - 펄플렉서티(PPL): 언어 모델을 평가하기 위한 평가 지표
#     - 'perplexed'는 '헷갈리는'과 유사한 의미
#     - PPL은 '헷갈리는 정도'로 이해
#     - PPL은 수치가 높으면 좋은 성능을 의미하는 것이 아니라, '낮을수록' 언어 모델의 성능이 좋다는 것을 의미한다는 점
# - PPL은 문장의 길이로 정규화된 문장 확률의 역수
# - ![image.png](attachment:image.png)

# %% [markdown]
# ### 분기 계수(Branching factor)
# - PPL은 선택할 수 있는 가능한 경우의 수를 의미하는 분기계수(branching factor)
# - ex. PPL이 10이 나왔다
#     - 해당 언어 모델은 테스트 데이터에 대해서 다음 단어를 예측하는 모든 시점(time step)마다 평균 10개의 단어를 가지고 어떤 것이 정답인지 고민한다는 것
#     - 두 언어 모델 중 PPL이 더 낮은 언어 모델의 성능이 더 좋다고 볼 수 있음
# - 주의할 점
#     - PPL의 값이 낮다는 것은 테스트 데이터 상에서 높은 정확도를 보인다는 것, 사람이 직접 느끼기에 좋은 언어 모델이라는 것을 반드시 의미하진 않음
#     - 테스트 데이터에 의존하므로 두 개 이상의 언어 모델을 비교할 때는 정량적으로 양이 많고, 또한 도메인에 알맞은 동일한 테스트 데이터를 사용해야 신뢰도가 높음

# %% [markdown]
# ### 기존 언어 모델 Vs. 인공 신경망을 이용한 언어 모델
# - ![image.png](attachment:image.png)
# - 페이스북ai 연구팀 성능 테스트
# - 5gram은 일반화(generalized)방법이 사용된 모델
# - 결과적으로는 인공 신경망 모델들이 더 좋은 성능 평가 받음
