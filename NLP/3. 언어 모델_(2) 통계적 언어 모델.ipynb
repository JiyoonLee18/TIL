# %% [markdown]
# ## 통계적 언어 모델(Statistical Language Model, SLM)
# - https://wikidocs.net/21687
# - 전통적인 접근 방법

# %% [markdown]
# ### 조건부 확률
# - 두 확률 P(A), P(B)
# - ![image.png](attachment:image.png)
# - 더 많은 확률 (4개)
# - ![image-2.png](attachment:image-2.png)
# - 조건부 확률의 연쇄 법칙(chain rule) (n개)
# - ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ### 문장에 대한 확률
# - 문장 'An adorable little boy is spreading smiles'의 확률:
#     - P(An adorable little boy is spreading smiles)식으로 표현
#     - ![image.png](attachment:image.png)

# %% [markdown]
# ### 카운트 기반의 접근
# - 이전 단어로부터 다음 단어에 대한 확률: 카운트에 기반하여 확률을 계산
# - An adorable little boy가 나왔을 때, is가 나올 확률: P(is|An adorable little boy)
# - ![image.png](attachment:image.png)
# - ex. 코퍼스에 An adorable little boy가 100번 등장, 그리고 그 다음에 is가 등장하는 경우가 30번 -> P(is|An adorable little boy)는 30%

# %% [markdown]
# ### 카운트 기반 접근의 한계 - 희소 문제(Sparsity Problem)
# - 기계에게 많은 코퍼스를 훈련시켜서 언어 모델을 통해 현실에서의 확률 분포를 근사하는 것이 언어 모델의 목표
#     - 방대한 양이 필요
#     - 희소 문제: 충분한 데이터를 관측하지 못하여 언어를 정확히 모델링하지 못하는 문제
# - 문제를 완화하는 방법
#     - n-gram 언어 모델, 스무딩이나 백오프와 같은 여러가지 일반화(generalization) 기법이 존재
#     - 희소 문제에 대한 근본적인 해결책은 되지 못함 -> 트렌드 통계적 언어 모델에서 인공 신경망 언어 모델로 이동
