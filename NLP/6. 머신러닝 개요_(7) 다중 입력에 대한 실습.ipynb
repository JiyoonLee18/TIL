# %% [markdown]
# ## 다중 입력에 대한 실습
# - https://wikidocs.net/35821
# - 독립변수 x가 2개 이상인 경우에 대해서 학습
# - 비용함수와 옵티마이저 등을 사용하는 방법은 동일

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras import optimizers

# %% [markdown]
# ### 다중 선형 회귀
# - 대부분의 입력들은 독립 변수가 2개 이상
#     - 입력 벡터의 차원이 2이상
# - 예) y를 결정하는 독립변수가 3개인 선형 회귀
#     - 중간고사, 기말고사, 추가점수를 어떤 공식을 통해 최종 점수를 계산한 데이터
#     ![image.png](attachment:image.png)
#     - 입력의 차원이 3으로 바뀌면서 input_dim의 인자값이 3으로 변경됨
#     - 입력벡터의 X의 원소의 개수가 3개라고도 표현
#     - 입력벡터 X의 차원이 3임을 의미

# %%
# 중간 고사, 기말 고사, 가산점 점수
X = np.array([[70,85,11], [71,89,18], [50,80,20], [99,20,10], [50,10,10]]) 
y = np.array([73, 82 ,72, 57, 34]) # 최종 성적

model = Sequential()
model.add(Dense(1, input_dim=3, activation='linear'))

sgd = optimizers.SGD(lr=0.0001)
model.compile(optimizer=sgd, loss='mse', metrics=['mse'])
model.fit(X, y, epochs=2000)
# Out:
# Epoch 1/2000
# C:\Users\JiyoonLee\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 1/1 [==============================] - 0s 353ms/step - loss: 1496.9006 - mse: 1496.9006
# Epoch 2/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 825.6175 - mse: 825.6175
# Epoch 3/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 470.5611 - mse: 470.5611
# Epoch 4/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 282.5320 - mse: 282.5320
# Epoch 5/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 182.7687 - mse: 182.7687
# Epoch 6/2000
# 1/1 [==============================] - 0s 4ms/step - loss: 129.6787 - mse: 129.6787
# Epoch 7/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 101.2879 - mse: 101.2879
# Epoch 8/2000
# ...

# %%
# y = np.array([73, 82 ,72, 57, 34]
print(model.predict(X))
# Out:
# 1/1 [==============================] - 0s 50ms/step
# [[72.94726 ]
#  [81.97089 ]
#  [72.084656]
#  [57.11278 ]
#  [33.807667]]

# %%
X_test = np.array([[20,99,10], [40,50,20]])
print(model.predict(X_test))
# Out:
# 1/1 [==============================] - 0s 13ms/step
# [[57.93385 ]
#  [56.043236]]

# %% [markdown]
# ### 다중 로지스틱 회귀
# - y를 결정하는데 있어 독립 변수 x가 2개인 로지스틱 회귀
# - 예) 꽃받침의 길이와 꽃잎의 길이에 따라 해당 꽃이 A인지 B인지 적혀있는 데이터
# ![image.png](attachment:image.png)
# - 예) 독립 변수 x1, x2의 합이 2 이상이면 출력값 y가 1이 되고 두 개의 입력 값 합이 2 미만인 경우 출력값 0이 되는 예제
# - 입력의 차원이 2 -> input_dim의 값이 2

# %%
X = np.array([[0, 0], [0, 1], [1, 0], [0, 2], [1, 1], [2, 0]])
y = np.array([0, 0, 0, 1, 1, 1])

model = Sequential()
model.add(Dense(1, input_dim=2, activation='sigmoid'))
model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['binary_accuracy'])

model.fit(X, y, epochs=2000)
# Out:
# Epoch 1/2000
# 1/1 [==============================] - 0s 241ms/step - loss: 1.0724 - binary_accuracy: 0.5000
# Epoch 2/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0704 - binary_accuracy: 0.3333
# Epoch 3/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0683 - binary_accuracy: 0.3333
# Epoch 4/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0663 - binary_accuracy: 0.3333
# Epoch 5/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0643 - binary_accuracy: 0.3333
# Epoch 6/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0623 - binary_accuracy: 0.3333
# Epoch 7/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0603 - binary_accuracy: 0.3333
# Epoch 8/2000
# 1/1 [==============================] - 0s 3ms/step - loss: 1.0583 - binary_accuracy: 0.3333
# Epoch 9/2000
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0563 - binary_accuracy: 0.3333
# Epoch 10/2000
# ...

# %%
# y = np.array([0, 0, 0, 1, 1, 1])
print(model.predict(X))
# Out:
# 1/1 [==============================] - 0s 28ms/step
# [[0.21754828]
#  [0.47094932]
#  [0.482259  ]
#  [0.7402645 ]
#  [0.7488867 ]
#  [0.7573165 ]]

# %% [markdown]
# ### 인공 신경망 다이어그램
# - 스킵
# ![image.png](attachment:image.png)
